# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/purchase_data.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263014 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
#Get basic statistical information about this dataset, check for null values and duplicates values in the data

#1. for statistical info
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  9.035400e+04  90353.000000    90353.000000        90353.000000
# mean   1.002744e+06      8.087866        0.410412            5.300001
# std    1.764520e+03      6.559983        0.491911            3.733615
# min    1.000001e+06      0.000000        0.000000            1.000000
# 25%    1.001194e+06      2.000000        0.000000            1.000000
# 50%    1.002544e+06      7.000000        0.000000            5.000000
# 75%    1.004257e+06     14.000000        1.000000            8.000000
# max    1.006040e+06     20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3      Purchase
# count        62120.000000        27499.000000  90353.000000
# mean             9.861317           12.656097   9292.215732
# std              5.084147            4.128635   4963.411008
# min              2.000000            3.000000    185.000000
# ...

# %%
#describe fxn for categorical order
df.describe(include ='O')		# O - object datatype
# Out:
#        Product_ID Gender    Age City_Category Stay_In_Current_City_Years
# count       90354  90354  90354         90353                      90353
# unique       3299      2      8             3                          5
# top     P00025442      M  26-35             B                          1
# freq          276  68334  35913         37926                      31460

# %%
#2. check null values
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             81514
# Product_Category_3            182433
# Purchase                           1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(263956)

# %%
#3. check duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove null values
df.dropna(inplace=True)       #inpalce = True to update the changes in our actual dataframe

# %%
df.shape
# Out:
# (80582, 12)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
#now we need to see all the unique values in the data
#(for this, we have unique(),   nunique(),   value_counts() )

df['Age'].unique()
# Out:
# array(['0-17', '46-50', '26-35', '51-55', '36-45', '18-25', '55+'],
#       dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '1', '4+', '0', '3'], dtype=object)

# %%
#now we want to check the number of unique values present in our UserID coloumn
df['User_ID'].nunique()                      #nunique = number of unique values present in the data
# Out:
# 4868

# %%
#now we want to check the frequency of each unique values in Gender column
df['Gender'].value_counts()
# Out:
# Gender
# M    62549
# F    18033
# Name: count, dtype: int64

# %%
#now converting all categorical data into number

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
for x in df.columns:
  if df[x].dtype=='object':
    df[x] = le.fit_transform(df[x])

# %%
df
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1       1000001         391       0    0        10.0              0
# 6       1000004         284       1    4         7.0              1
# 13      1000005         211       1    2        20.0              0
# 14      1000006         363       0    5         9.0              0
# 16      1000006         517       0    5         9.0              0
# ...         ...         ...     ...  ...         ...            ...
# 262997  1004472         402       0    4        16.0              1
# 263001  1004472         337       0    4        16.0              1
# 263003  1004472         480       0    4        16.0              1
# 263006  1004472          49       0    4        16.0              1
# 263011  1004473         159       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                                2             0.0                 1.0
# ...

# %%
df.info()   #now al the columns are numerical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80582 entries, 1 to 263011
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     80582 non-null  int64
#  1   Product_ID                  80582 non-null  int64
#  2   Gender                      80582 non-null  int64
#  3   Age                         80582 non-null  int64
#  4   Occupation                  80582 non-null  float64
#  5   City_Category               80582 non-null  int64
#  6   Stay_In_Current_City_Years  80582 non-null  int64
#  7   Marital_Status              80582 non-null  float64
#  8   Product_Category_1          80582 non-null  float64
#  9   Product_Category_2          80582 non-null  float64
#  10  Product_Category_3          80582 non-null  float64
#  11  Purchase                    80582 non-null  float64
# dtypes: float64(6), int64(6)
# memory usage: 8.0 MB

# %%
#Steps to follow:

1. Note down the null and alternate hypothesis
2. Create a new or sub dataset based on the condition (Problem Statement)
3. Now the new data will be our entire population, from this population we will create a new sample
4. We will perform hypothesis testing and do the conclusion

# %%
#Q1. Lets suppose it was ovserved that the average purchase made by the Men of age group 18-25 was 10000. Is it still the same


H0: Avg purchase made by the Men of age group 18-25 is 10000 (no sign difference)
Ha: Avg purchase made by the Men of age group 18-25 is not 10000 (sign difference)

# %%
new_data = df[(df['Age']==1) & (df['Gender']==1)]  	#age ==1 (18-25 group & Gender == 1(Male))
new_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 98      1000022         487       1    1        15.0              0
# 103     1000022         402       1    1        15.0              0
# 111     1000022         358       1    1        15.0              0
# 127     1000025         332       1    1         4.0              2
# 128     1000025          71       1    1         4.0              2
# ...         ...         ...     ...  ...         ...            ...
# 262758  1004446         180       1    1        18.0              1
# 262759  1004446         394       1    1        18.0              1
# 262760  1004446          23       1    1        18.0              1
# 262764  1004446          75       1    1        18.0              1
# 262952  1004465         209       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 98                               4             0.0                 1.0
# ...

# %%
sample_size = 1000  	#we select 10-20% data as sample

new_data_sample = new_data.sample(sample_size, random_state = 20)	#random_state -> it will behave like seed
new_data_sample
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 225292  1004695           0       1    1        18.0              2
# 7862    1001221          59       1    1         0.0              1
# 209222  1002186          99       1    1         5.0              2
# 255112  1003391         290       1    1         4.0              0
# 214324  1003112         163       1    1        12.0              0
# ...         ...         ...     ...  ...         ...            ...
# 209571  1002242         432       1    1         4.0              0
# 76056   1005730          85       1    1         0.0              0
# 156653  1000192         254       1    1         1.0              1
# 207825  1002010         155       1    1         4.0              1
# 245021  1001733         290       1    1        14.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 225292                           4             0.0                 3.0
# ...

# %%
#one sample ttest

from scipy.stats import ttest_1samp

t_stat, p_value = ttest_1samp(new_data_sample['Purchase'], 10000)     #10000 value we are checking (given in the ques)

# %%
p_value
# Out:
# np.float64(3.768003517176592e-32)

# %%
if p_value < 0.05:
	print ('Reject H0: Avg purchase made by the Men of age group 18-25 is not 10000 (sign difference)' )

else:
	print('Accept H0: Avg purchase made by the Men of age group 18-25 is 10000 (no sign difference)')
# Out:
# Reject H0: Avg purchase made by the Men of age group 18-25 is not 10000 (sign difference)

# %%
#Q2. Is the average purhcase made by men and women of age 18-25 is same?

H0 = average purhcase made by men and women of age 18-25 is same
Ha = average purhcase made by men and women of age 18-25 is not same

# %%
#we need to select our populatopm
- first group (men)-> 18-25
- second group (women)-> 18-25

# %%
#first group (men)-> 18-25
new_data_male = df[(df['Age']==1) & (df['Gender']==1)]            #All male (Gender == 1) of age 18-25 group (age == 1)
new_data_male
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 98      1000022         487       1    1        15.0              0
# 103     1000022         402       1    1        15.0              0
# 111     1000022         358       1    1        15.0              0
# 127     1000025         332       1    1         4.0              2
# 128     1000025          71       1    1         4.0              2
# ...         ...         ...     ...  ...         ...            ...
# 262758  1004446         180       1    1        18.0              1
# 262759  1004446         394       1    1        18.0              1
# 262760  1004446          23       1    1        18.0              1
# 262764  1004446          75       1    1        18.0              1
# 262952  1004465         209       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 98                               4             0.0                 1.0
# ...

# %%
sample_size = 600

new_sample_male = new_data_male.sample(sample_size, random_state = 0)
new_sample_male
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 124490  1001221         184       1    1         0.0              1
# 66720   1004217           6       1    1         4.0              1
# 194073  1005964         418       1    1         5.0              1
# 157342  1000302         262       1    1         4.0              1
# 199012  1000742         411       1    1         0.0              2
# ...         ...         ...     ...  ...         ...            ...
# 82256   1000714         109       1    1         4.0              1
# 33594   1005156         231       1    1        14.0              0
# 128556  1001764         137       1    1         0.0              1
# 79922   1000306         322       1    1         0.0              2
# 256938  1003622         513       1    1         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 124490                           1             0.0                 1.0
# ...

# %%
#second group (women)-> 18-25
new_data_female = df[(df['Age']==1) & (df['Gender']==0)]        #All female (Gender == 0) of age 18-25 group (age == 1)
new_data_female
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 71      1000018         300       0    1         3.0              1
# 72      1000018         229       0    1         3.0              1
# 73      1000018         152       0    1         3.0              1
# 75      1000018          51       0    1         3.0              1
# 76      1000018         351       0    1         3.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262254  1004371         232       0    1         4.0              1
# 262383  1004387         309       0    1         4.0              1
# 262403  1004387         207       0    1         4.0              1
# 262411  1004387         105       0    1         4.0              1
# 262415  1004387         193       0    1         4.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 71                               3             0.0                 3.0
# ...

# %%
sample_size = 600

new_sample_female = new_data_female.sample(sample_size, random_state = 0)
new_sample_female
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 178294  1003580         210       0    1         3.0              2
# 11690   1001755         135       0    1         4.0              1
# 1949    1000310         191       0    1         4.0              2
# 110793  1005061         350       0    1        19.0              2
# 35085   1005419         149       0    1        12.0              2
# ...         ...         ...     ...  ...         ...            ...
# 56340   1002684         326       0    1         0.0              2
# 38700   1005959           0       0    1         4.0              1
# 11270   1001697         342       0    1         4.0              1
# 193286  1005847         438       0    1         4.0              1
# 96043   1002885          99       0    1         1.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 178294                           0             0.0                 1.0
# ...

# %%
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(new_sample_male['Purchase'], new_sample_female['Purchase'])

# %%
p_value
# Out:
# np.float64(0.0001236710854620484)

# %%
if p_value < 0.05:
	print ('Reject H0: average purhcase made by men and women of age 18-25 is not same' )

else:
	print('Accept H0: average purhcase made by men and women of age 18-25 is same')
# Out:
# Reject H0: average purhcase made by men and women of age 18-25 is not same

# %%
#Q3. Is the proportion distribution of men who have spend more than 10000 is same for the ages 18-25 and 26-35

H0 = Men who have spend more than 10000 are same for the age 18-25 and 26-35
H0 = Men who have spend more than 10000 are not same for the age 18-25 and 26-35

# %%
df_new = df[df['Purchase']>10000]
df_new
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1       1000001         391       0    0        10.0              0
# 6       1000004         284       1    4         7.0              1
# 13      1000005         211       1    2        20.0              0
# 16      1000006         517       0    5         9.0              0
# 18      1000007          58       1    3         1.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262995  1004472         175       0    4        16.0              1
# 262997  1004472         402       0    4        16.0              1
# 263001  1004472         337       0    4        16.0              1
# 263003  1004472         480       0    4        16.0              1
# 263011  1004473         159       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                                2             0.0                 1.0
# ...

# %%
data_men_1 = df_new[(df_new['Gender']== 1) & (df_new['Age'] == 1)]
data_men_1
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 98      1000022         487       1    1        15.0              0
# 103     1000022         402       1    1        15.0              0
# 127     1000025         332       1    1         4.0              2
# 128     1000025          71       1    1         4.0              2
# 221     1000039         487       1    1         4.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262553  1004411         309       1    1         4.0              0
# 262563  1004412         212       1    1         4.0              2
# 262577  1004416         418       1    1         4.0              0
# 262758  1004446         180       1    1        18.0              1
# 262759  1004446         394       1    1        18.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 98                               4             0.0                 1.0
# ...

# %%
data_men_2 = df_new[(df_new['Gender']== 1) & (df_new['Age'] == 2)]
data_men_2
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 13      1000005         211       1    2        20.0              0
# 19      1000008         393       1    2        12.0              2
# 24      1000008         438       1    2        12.0              2
# 64      1000015          64       1    2         7.0              0
# 198     1000036         479       1    2         3.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262939  1004461         266       1    2        20.0              2
# 262941  1004461         241       1    2        20.0              2
# 262944  1004461          91       1    2        20.0              2
# 262945  1004461          93       1    2        20.0              2
# 262987  1004471         154       1    2         6.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 13                               1             1.0                 1.0
# ...

# %%
sample_size = 900
data_men_1 = data_men_1.sample(sample_size, random_state = 25)

# %%
sample_size = 900
data_men_2 = data_men_2.sample(sample_size, random_state = 25)

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
total_count = [df[(df['Gender']== 1) & (df['Age'] == 1)].shape[0], df[(df['Gender']== 1) & (df['Age'] == 2)].shape[0]]
total_count
# Out:
# [11904, 25787]

# %%
t_stats, p_value = proportions_ztest(count = [1000,1000], nobs = total_count)         #sample_size = [900,900]  and nobs = no of observation

# %%
if p_value < 0.05:
	print ('Reject H0: Men who have spend more than 10000 are not same for the age 18-25 and 26-35' )

else:
	print('Accept H0: Men who have spend more than 10000 are same for the age 18-25 and 26-35')
# Out:
# Reject H0: Men who have spend more than 10000 are not same for the age 18-25 and 26-35
