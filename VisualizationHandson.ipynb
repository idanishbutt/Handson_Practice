# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('/content/cars (1).csv')
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
df.info()     #summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
df.describe()     #it gives statstical data (numerical value)
# Out:
#               mpg   cylinders          hp  time-to-60         year
# count  261.000000  261.000000  261.000000  261.000000   261.000000
# mean    23.144828    5.590038  106.360153   15.547893  1976.819923
# std      7.823570    1.733310   40.499959    2.910625     3.637696
# min     10.000000    3.000000   46.000000    8.000000  1971.000000
# 25%     16.900000    4.000000   75.000000   14.000000  1974.000000
# 50%     22.000000    6.000000   95.000000   16.000000  1977.000000
# 75%     28.800000    8.000000  138.000000   17.000000  1980.000000
# max     46.600000    8.000000  230.000000   25.000000  1983.000000

# %%
#check null values
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    0
# hp             0
# weightlbs      0
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
#check null values in the whole dataset
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#lEts pretend we have null values

either we can drop the data or fill the data which all depends

#if we are something dropping
df.dropna(inpalce = True)

#checking for duplicates values
df.duplicated().sum()
# Out:
#   File "<ipython-input-10-b75cc16b39e3>", line 3
#     either we can drop the data or fill the data which all depends
#            ^
# SyntaxError: invalid syntax

# %%
#lEts pretend we have duplicated values as well
df.drop_duplicates(inpalce = True)

# %%
#Plot multiple graphs in one

# %% [markdown]
# subplot
# ![image.png](data:image/png;base64,...)

# %%
#1. Create scatter plots for the following data, make sure all the appear in the same plane with x-label and and y-labels evenly placed

- Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg,hp-time-to-60) with respect to each brand

# %%
fig = plt.subplots(2,2, figsize =(20,10))

#mpg-hp
plt.subplot(2,2,1)  #focuses on the first graph
sns.scatterplot(x= df['mpg'], y =df['hp'], hue=df['brand'])       #hue - differentiates categories on the plot wrt a column
plt.title ('MPG vs HP')
plt.xlabel('MPG')
plt.ylabel('HP')

#mpg-weight
plt.subplot(2,2,2)  #focuses on the second graph
sns.scatterplot(x= df['mpg'], y =df['weightlbs'], hue=df['brand'])
plt.title ('MPG vs WEIGHT')
plt.xlabel('MPG')
plt.ylabel('WEIGHT')

#hp-mpg
plt.subplot(2,2,3)  #focuses on the third graph
sns.scatterplot(x= df['hp'], y =df['hp'], hue=df['brand'])
plt.title ('HP vs MPG')
plt.xlabel('HP')
plt.ylabel('MPG')

#hp-time-to-60
plt.subplot(2,2,4)  #focuses on the fourth graph
sns.scatterplot(x= df['hp'], y =df['time-to-60'], hue=df['brand'])
plt.title ('HP vs TIME-TO-60')
plt.xlabel('HP')
plt.ylabel('TIME-TO-60')


plt.show()

# %%
fig = plt.subplots(1,1, figsize =(10,50))

plt.subplot(1,1,1)  #focuses on the second graph
sns.scatterplot(x= df['mpg'], y =df['weightlbs'], hue=df['brand'])
plt.title ('MPG vs WEIGHT')
plt.xlabel('MPG')
plt.ylabel('WEIGHT')
# Out:
# Text(0, 0.5, 'WEIGHT')

# %%
#2. Create bar plots for the following, make sure all the plots appear in the same plane with x- labels and y-labels evenly placed

- Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.

# %%
figure = plt.subplots(2,2, figsize = (20,10))

#HP vs Cylinder
plt.subplot(2,2,1)
sns.barplot(x = df['hp'], y = df['cylinders'], hue = df['brand'])
plt.title('HP vs Cylinder')
plt.xlabel('HP')
plt.ylabel('Cylinder')

#MPG vs Cylinder
plt.subplot(2,2,2)
sns.barplot(x = df['mpg'], y = df['cylinders'], hue = df['brand'])
plt.title('MPG vs Cylinder')
plt.xlabel('MPG')
plt.ylabel('Cylinder')

#WEIGHT vs Cylinder
plt.subplot(2,2,3)
sns.barplot(x = df['weightlbs'], y = df['cylinders'], hue = df['brand'])
plt.title('WEIGHT vs Cylinder')
plt.xlabel('WEIGHT')
plt.ylabel('Cylinder')

#HP vs Cylinder
plt.subplot(2,2,4)
sns.barplot(x = df['time-to-60'], y = df['cylinders'], hue = df['brand'])
plt.title('HP vs Cylinder')
plt.xlabel('Time-to-60')
plt.ylabel('Cylinder')

plt.show()

# %%
-# Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.

# %%
figure = plt.subplots(2,2, figsize = (20,10))

#HP vs Cylinder
plt.subplot(2,2,1)
sns.barplot(x = df['hp'], y = df['year'], hue = df['brand'])
plt.title('HP vs YEAR')
plt.xlabel('HP')
plt.ylabel('Year')

#MPG vs Cylinder
plt.subplot(2,2,2)
sns.barplot(x = df['mpg'], y = df['year'], hue = df['brand'])
plt.title('MPG vs YEAR')
plt.xlabel('MPG')
plt.ylabel('Year')

#WEIGHT vs Cylinder
plt.subplot(2,2,3)
sns.barplot(x = df['weightlbs'], y = df['year'], hue = df['brand'])
plt.title('WEIGHT vs YEAR')
plt.xlabel('WEIGHT')
plt.ylabel('Year')

#HP vs Cylinder
plt.subplot(2,2,4)
sns.barplot(x = df['time-to-60'], y = df['year'], hue = df['brand'])
plt.title('HP vs YEAR')
plt.xlabel('Time-to-60')
plt.ylabel('Year')

plt.show()

# %%
-# Create a box plots for the following:
- Create box plots for the columns (hp,mpg,weight,time-to-60) in the step1 with respect to the number of cylinders and brand respectively

# %%
figure = plt.subplots(2,2, figsize = (20,10))

#HP vs Cylinder
plt.subplot(2,2,1)
sns.boxplot(x = df['hp'], y = df['cylinders'], hue = df['brand'])
plt.title('HP vs Cylinder')
plt.xlabel('HP')
plt.ylabel('Cylinder')

#MPG vs Cylinder
plt.subplot(2,2,2)
sns.boxplot(x = df['mpg'], y = df['cylinders'], hue = df['brand'])
plt.title('MPG vs Cylinder')
plt.xlabel('MPG')
plt.ylabel('Cylinder')

#WEIGHT vs Cylinder
plt.subplot(2,2,3)
sns.boxplot(x = df['weightlbs'], y = df['cylinders'], hue = df['brand'])
plt.title('WEIGHT vs Cylinder')
plt.xlabel('WEIGHT')
plt.ylabel('Cylinder')

#HP vs Cylinder
plt.subplot(2,2,4)
sns.boxplot(x = df['time-to-60'], y = df['cylinders'], hue = df['brand'])
plt.title('HP vs Cylinder')
plt.xlabel('Time-to-60')
plt.ylabel('Cylinder')

plt.show()

# %%
-# Create pair plots for entire data to study various patterns in the data

- Create pair plots with respect to brand, number of cylinders, year etc

# %%
sns.pairplot(df)

# %%
#KDE - Kernel Density Estimation : smoother version of histogram
sns.pairplot(df, hue = 'brand')

# %%
# correlation - relationship between 2 numerical columns
# heatmap = color coded 2D matrix (shows concentrations of the data)

# %%
#- Create a heatmap for the entire data to study correlation between each of the columns
c=df.corr(numeric_only= True)  #select only numerical values

sns.heatmap(c, annot = True)      #annot is usually used to show the exact value holding the data
# Out:
# <Axes: >

# %%
#- Create a histogram for the following:
- Create a histogram for hp, mpg, time-to-60, weight-lbs, cubic inches, year with respect to brand

# %%
#histogram: UNivariate (work with one column)

fig = plt.subplots(3,2, figsize=(20,10))

plt.subplot(3,2,1)
sns.histplot(data = df, x='hp', hue='brand')
plt.xlabel('Horsepower')


plt.subplot(3,2,2)
sns.histplot(data = df, x='mpg', hue='brand')
plt.xlabel('Miles per Gallon')


plt.subplot(3,2,3)
sns.histplot(data = df, x='time-to-60', hue='brand')
plt.xlabel('0-60 Time')


plt.subplot(3,2,4)
sns.histplot(data = df, x='weightlbs', hue='brand')
plt.xlabel('Weight (lbs)')


plt.subplot(3,2,5)
sns.histplot(data = df, x='cubicinches', hue='brand')
plt.xlabel('Cubic Inches')


plt.subplot(3,2,6)
sns.histplot(data = df, x='year', hue='brand')
plt.xlabel('Year')
plt.show()
